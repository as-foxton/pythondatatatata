# %%
import pandas
from json import loads, dumps

# %%
bestand = pandas.read_csv("lfsi_emp_a_h.csv")
bestand
# Out:
#           age     unit sex indic_em geo  year employment
# 0      Y15-24   PC_POP   F      ACT  AT  2020      52.8
# 1      Y15-24   PC_POP   F      ACT  BE  2020      26.5
# 2      Y15-24   PC_POP   F      ACT  BG  2020      18.2
# 3      Y15-24   PC_POP   F      ACT  CH  2020      64.6
# 4      Y15-24   PC_POP   F      ACT  CY  2020      36.6
# ...       ...      ...  ..      ...  ..   ...        ...
# 69943  Y55-64  THS_PER   T  EMP_LFS  SE  1992         :
# 69944  Y55-64  THS_PER   T  EMP_LFS  SI  1992         :
# 69945  Y55-64  THS_PER   T  EMP_LFS  SK  1992         :
# 69946  Y55-64  THS_PER   T  EMP_LFS  TR  1992         :
# 69947  Y55-64  THS_PER   T  EMP_LFS  UK  1992         :
#
# [69948 rows x 7 columns]

# %%
bestand = pandas.read_csv("marketing_sample_for_naukri_com-jobs__20190701_20190830__30k_data.csv")
bestand
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1      3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2      ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3      7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4      2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# ...                                 ...                        ...
# 29995  3510f2146b514f112eaa9706a16b3900  2019-07-06 21:12:51 +0000
# 29996  4af8c56f5b4c535b1974065003f2d548  2019-08-05 23:55:08 +0000
# 29997  43d5b806b26ed99d3ebfc8f366b4cdd1  2019-08-05 09:41:29 +0000
# 29998  8bc87d14cf56564f16b6d4bae80180be  2019-08-06 01:44:55 +0000
# 29999  9c7045d111814a6f39fe461eab2b0bf8  2019-07-06 22:24:55 +0000
#
#                                                Job Title  \
# 0                                  Digital Media Planner
# ...

# %%
bestand["Job Salary"] = bestand["Job Salary"].str.replace(" ", "")
bestand
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1      3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2      ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3      7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4      2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# ...                                 ...                        ...
# 29995  3510f2146b514f112eaa9706a16b3900  2019-07-06 21:12:51 +0000
# 29996  4af8c56f5b4c535b1974065003f2d548  2019-08-05 23:55:08 +0000
# 29997  43d5b806b26ed99d3ebfc8f366b4cdd1  2019-08-05 09:41:29 +0000
# 29998  8bc87d14cf56564f16b6d4bae80180be  2019-08-06 01:44:55 +0000
# 29999  9c7045d111814a6f39fe461eab2b0bf8  2019-07-06 22:24:55 +0000
#
#                                                Job Title  \
# 0                                  Digital Media Planner
# ...

# %%
bestand["Job Salary"] = bestand["Job Salary"].str.replace(" ", "")
bestand
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1      3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2      ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3      7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4      2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# ...                                 ...                        ...
# 29995  3510f2146b514f112eaa9706a16b3900  2019-07-06 21:12:51 +0000
# 29996  4af8c56f5b4c535b1974065003f2d548  2019-08-05 23:55:08 +0000
# 29997  43d5b806b26ed99d3ebfc8f366b4cdd1  2019-08-05 09:41:29 +0000
# 29998  8bc87d14cf56564f16b6d4bae80180be  2019-08-06 01:44:55 +0000
# 29999  9c7045d111814a6f39fe461eab2b0bf8  2019-07-06 22:24:55 +0000
#
#                                                Job Title  \
# 0                                  Digital Media Planner
# ...

# %%
# s=" Not Disclosed by Recruiter"
# s.replace(" ", "")

# %%
import re

def convert_to_average(s):
    # Extract the numbers from the string
    numbers = re.findall(r'[0-9,]+', s)
    
    # Remove commas and convert to integers
    numbers = [int(n.replace(',', '')) for n in numbers]
    
    # Calculate the average
    # print(type(numbers))
    average = sum(numbers) / len(numbers)
    
    return average

s = "123213"
average = convert_to_average(s)
average
# Out:
# 123213.0

# %%
text="Nobar1"
has_number = False

for char in text:
    if char.isdigit():
        has_number = True
        break  # Once a digit is found, exit the loop

if has_number:
    print("The string contains a number.")
else:
    print("The string does not contain a number.")
# Out:
# The string contains a number.

# %%
bestand
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1      3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2      ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3      7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4      2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# ...                                 ...                        ...
# 29995  3510f2146b514f112eaa9706a16b3900  2019-07-06 21:12:51 +0000
# 29996  4af8c56f5b4c535b1974065003f2d548  2019-08-05 23:55:08 +0000
# 29997  43d5b806b26ed99d3ebfc8f366b4cdd1  2019-08-05 09:41:29 +0000
# 29998  8bc87d14cf56564f16b6d4bae80180be  2019-08-06 01:44:55 +0000
# 29999  9c7045d111814a6f39fe461eab2b0bf8  2019-07-06 22:24:55 +0000
#
#                                                Job Title  \
# 0                                  Digital Media Planner
# ...

# %%
# regular expression to match the pattern
pattern = r'\d+(,\d{2,3})*-\d+(,\d{2,3})*PA\.$'
mask=bestand['Job Salary'].str.contains(pattern)
mask2 = bestand['Job Salary'].apply(lambda x: isinstance(x, list))
y=0
# filtered_df=bestand[mask]
for i,job in bestand.iterrows():
# job["Job Salary"].replace(" ", "")
    if type(job["Job Salary"])==float:
        pass
    else:
        has_number=False
        for char in job["Job Salary"]:
            if char.isdigit():
                has_number=True
                break
        
        if "Opening" in job["Job Salary"]:
            pass
        elif has_number==False:
            pass
        # elif "," in job["Job Salary"]:
            # pass
        elif mask[i]:
            # if(job["Job Salary"]=="NotDisclosedbyRecruiter"):
                # job['Average Salary']="Not Disclosed by Recruiter"
                # print("Not Disclosed by Recruiter")
                # pass
            # else:
            
            print(job["Job Salary"])

            job['Average Salary']=convert_to_average(job["Job Salary"])
            print(job["Average Salary"])
            y=y+1
        elif mask2[i]:
            pass
        elif "PA" in job["Job Salary"]:
            # print(job["Job Salary"])
            pass

        else:
           pass 
            # print(job["Average Salary"])

print(y)




# create a boolean mask
# mask = 

# filter the DataFrame using the mask
# filtered_df = df[mask]


# replace list cells with NaN
# df_no_lists = df.where(~mask, np.nan)

# print(df_no_lists)
# Out:
# C:\Users\Jefta\AppData\Local\Temp\ipykernel_7108\2973700051.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask=bestand['Job Salary'].str.contains(pattern)
# 2,00,000-4,00,000PA.
# 300000.0
# 7,00,000-17,00,000PA.
# 1200000.0
# 2,00,000-3,00,000PA.
# 250000.0
# 25,00,000-35,00,000PA.
# 3000000.0
# 3,50,000-5,00,000PA.
# 425000.0
# 1,00,000-3,25,000PA.
# 212500.0
# 2,50,000-4,50,000PA.
# 350000.0
# 2,00,000-3,00,000PA.
# 250000.0
# 2,00,000-4,00,000PA.
# 300000.0
# 9,00,000-17,00,000PA.
# 1300000.0
# 1,00,000-4,00,000PA.
# 250000.0
# 2,00,000-3,75,000PA.
# 287500.0
# 19,00,000-25,00,000PA.
# 2200000.0
# 4,00,000-6,00,000PA.
# 500000.0
# 10,00,000-12,00,000PA.
# 1100000.0
# INR2,50,000-3,75,000PA.
# 312500.0
# INR20,00,000-30,00,000PA.
# 2500000.0
# 1,50,000-3,00,000PA.
# 225000.0
# 3,00,000-7,00,000PA.
# 500000.0
# 2,50,000-6,00,000PA.
# 425000.0
# 1,75,000-3,00,000PA.
# 237500.0
# ...

# %%
test= "2,00,000 - 4,00,000 PA."
if(test=="Not Disclosed by Recruiter"):
        print("Not Disclosed by Recruiter")
else:
    output=convert_to_average(test)
    print(output)
# Out:
# 300000.0

# %%
 # return "dit komt van jefta"

# jobid=87990
# bestand = pandas.read_csv("nyc-jobs.csv")
# for i,job in bestand.iterrows():
#   if(job["JobID"]==jobid):
#     print(methodejefta(87990))

# print(type(jobid))

# %%
def methodejefta(jobid):
  bestand = pandas.read_csv("marketing_sample_for_naukri_com-jobs__20190701_20190830__30k_data.csv")
  for i,job in bestand.iterrows():
    if(job["JobID"]==int(jobid)):
      pass
    else:
      bestand=bestand.drop(i)

  result=bestand.to_json(orient="records")
  parsed=loads(result)
  return dumps(parsed,indent=4)
# Out:
# 3000000.0

# %%
for i,job in bestand.head(10).iterrows():
    if type(job["Job Salary"]) == float:
        pass
    else:
        s=job["Job Salary"]
        print(type(job["Job Salary"]))
        s.replace(" ", "")
        # print(job["Job Salary"])  
        print(s)      
    # job["Job Salary"].replace(" ", "")
    # print(job["Job Salary"])
    # if type(job["Job Salary"]) == float:
    #     print(job["Job Salary"])
# bestand
# Out:
# <class 'str'>
#  Not Disclosed by Recruiter
# <class 'str'>
#  Not Disclosed by Recruiter
# <class 'str'>
#  Not Disclosed by Recruiter
# <class 'str'>
#  2,00,000 - 4,00,000 PA.
# <class 'str'>
#  Not Disclosed by Recruiter
# <class 'str'>
#  7,00,000 - 17,00,000 PA.
# <class 'str'>
#  2,00,000 - 3,00,000 PA.
# <class 'str'>
#  Not Disclosed by Recruiter
# <class 'str'>
#  Not Disclosed by Recruiter
# <class 'str'>
#  Not Disclosed by Recruiter
